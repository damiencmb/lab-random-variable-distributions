# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.Use the numerical variables from our dataset this week.

# %%
numerical = pd.read_csv('numerical_df').drop(['Year', 'Month', 'Day'], axis=1)
numerical
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                  69.0
# 1                 6979.535903       0                  94.0
# 2                12887.431650   48767                 108.0
# 3                 7645.861827       0                 106.0
# 4                 2813.692575   43836                  73.0
# ...                       ...     ...                   ...
# 9129              6279.177892   71941                  73.0
# 9130              3096.511217   21604                  79.0
# 9131              8163.890428       0                  85.0
# 9132              7524.442436   21941                  96.0
# 9133              2611.836866       0                  77.0
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# # 2.Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
for col in numerical.columns:
    sns.displot(numerical[col],kde=True)
    plt.show()

# %% [markdown]
# None of the column seem to have a normal distribution

# %% [markdown]
# # 3.Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %% [markdown]
# ## 3.1 Log transform

# %%
num_log=np.where(np.isfinite(np.log10(numerical)),np.log10(numerical),0)
num_log=pd.DataFrame(num_transformed,columns=numerical.columns)
num_log
# Out:
# /Users/damiencombe/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    3.441462  4.750308              1.838849
# 1                    3.843827  0.000000              1.973128
# 2                    4.110166  4.688126              2.033424
# 3                    3.883426  0.000000              2.025306
# 4                    3.449277  4.641831              1.863323
# ...                       ...       ...                   ...
# 9129                 3.797903  4.856976              1.863323
# 9130                 3.490873  4.334534              1.897627
# 9131                 3.911897  0.000000              1.929419
# 9132                 3.876474  4.341256              1.982271
# 9133                 3.416946  0.000000              1.886491
#
# ...

# %%
for col in num_log.columns:
    sns.displot(num_log[col],kde=True)
    plt.show()

# %% [markdown]
# ## 3.2 Square root tranform

# %%
num_sqrt=np.sqrt(numerical)
num_sqrt
# Out:
#       customer_lifetime_value      income  monthly_premium_auto  \
# 0                   52.569186  237.221416              8.306624
# 1                   83.543617    0.000000              9.695360
# 2                  113.522824  220.832516             10.392305
# 3                   87.440619    0.000000             10.295630
# 4                   53.044251  209.370485              8.544004
# ...                       ...         ...                   ...
# 9129                79.241264  268.218195              8.544004
# 9130                55.646305  146.982992              8.888194
# 9131                90.354250    0.000000              9.219544
# 9132                86.743544  148.124947              9.797959
# 9133                51.106133    0.000000              8.774964
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    5.656854                       2.236068
# 1                    3.605551                       6.480741
# ...

# %%
for col in num_sqrt.columns:
    sns.displot(num_sqrt[col],kde=True)
    plt.show()
